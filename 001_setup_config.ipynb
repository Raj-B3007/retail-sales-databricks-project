# %%
config_data = [
    ("DEV", "workspace", "default","reatail_dev_scope"),
    ("TEST", "workspace", "test","reatail_test_scope"),
    ("PROD", "workspace", "prod","reatail_prod_scope")
]

config_df = spark.createDataFrame(
    config_data,
    ["env", "catalog", "schema","secret_scope"]
)

(
    config_df
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("workspace.default.config_environment")
)

# display(spark.read.table("workspace.default.config_environment"))

#drop table
# spark.sql("DROP TABLE IF EXISTS workspace.default.config_environment")

#create prod schema
# spark.sql(f"CREATE SCHEMA IF NOT EXISTS PROD")
